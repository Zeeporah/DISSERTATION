# %%
import pandas as pd
from ydata_profiling import ProfileReport

UK_UNI = pd.read_csv('Populated UK UNI.csv')
profile = ProfileReport(UK_UNI)
profile.to_notebook_iframe()
# Out:
# ...
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/dani/SHU/students_github/DISSERTATION/data_summary.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/home/dani/SHU/students_github/DISSERTATION/data_summary.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> UK_UNI = pd.read_csv('Populated UK UNI.csv')
#       <a href='vscode-notebook-cell:/home/dani/SHU/students_github/DISSERTATION/data_summary.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> profile = ProfileReport(UK_UNI)
# ----> <a href='vscode-notebook-cell:/home/dani/SHU/students_github/DISSERTATION/data_summary.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> profile.to_notebook_iframe()
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:500, in ProfileReport.to_notebook_iframe(self)
#     498 with warnings.catch_warnings():
# ...
